# %%
# Display the Folders/Classes i
# Manual garbage collection process i
import gc ;
gc.collect() 
import numpy as np 
import pandas as pd 
import os 
fpath = "C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images"
print(os. listdir(fpath)) 
dog_classes = os.listdir(fpath)
# Out:
# ['n02085620-Chihuahua', 'n02085782-Japanese_spaniel', 'n02085936-Maltese_dog', 'n02086079-Pekinese', 'n02086240-Shih-Tzu', 'n02086646-Blenheim_spaniel', 'n02086910-papillon', 'n02087046-toy_terrier', 'n02087394-Rhodesian_ridgeback', 'n02088094-Afghan_hound', 'n02088238-basset', 'n02088364-beagle', 'n02088466-bloodhound', 'n02088632-bluetick', 'n02089078-black-and-tan_coonhound', 'n02089867-Walker_hound', 'n02089973-English_foxhound', 'n02090379-redbone', 'n02090622-borzoi', 'n02090721-Irish_wolfhound', 'n02091032-Italian_greyhound', 'n02091134-whippet', 'n02091244-Ibizan_hound', 'n02091467-Norwegian_elkhound', 'n02091635-otterhound', 'n02091831-Saluki', 'n02092002-Scottish_deerhound', 'n02092339-Weimaraner', 'n02093256-Staffordshire_bullterrier', 'n02093428-American_Staffordshire_terrier', 'n02093647-Bedlington_terrier', 'n02093754-Border_terrier', 'n02093859-Kerry_blue_terrier', 'n02093991-Irish_terrier', 'n02094114-Norfolk_terrier', 'n02094258-Norwich_terrier', 'n02094433-Yorkshire_terrier', 'n02095314-wire-haired_fox_terrier', 'n02095570-Lakeland_terrier', 'n02095889-Sealyham_terrier', 'n02096051-Airedale', 'n02096177-cairn', 'n02096294-Australian_terrier', 'n02096437-Dandie_Dinmont', 'n02096585-Boston_bull', 'n02097047-miniature_schnauzer', 'n02097130-giant_schnauzer', 'n02097209-standard_schnauzer', 'n02097298-Scotch_terrier', 'n02097474-Tibetan_terrier', 'n02097658-silky_terrier', 'n02098105-soft-coated_wheaten_terrier', 'n02098286-West_Highland_white_terrier', 'n02098413-Lhasa', 'n02099267-flat-coated_retriever', 'n02099429-curly-coated_retriever', 'n02099601-golden_retriever', 'n02099712-Labrador_retriever', 'n02099849-Chesapeake_Bay_retriever', 'n02100236-German_short-haired_pointer', 'n02100583-vizsla', 'n02100735-English_setter', 'n02100877-Irish_setter', 'n02101006-Gordon_setter', 'n02101388-Brittany_spaniel', 'n02101556-clumber', 'n02102040-English_springer', 'n02102177-Welsh_springer_spaniel', 'n02102318-cocker_spaniel', 'n02102480-Sussex_spaniel', 'n02102973-Irish_water_spaniel', 'n02104029-kuvasz', 'n02104365-schipperke', 'n02105056-groenendael', 'n02105162-malinois', 'n02105251-briard', 'n02105412-kelpie', 'n02105505-komondor', 'n02105641-Old_English_sheepdog', 'n02105855-Shetland_sheepdog', 'n02106030-collie', 'n02106166-Border_collie', 'n02106382-Bouvier_des_Flandres', 'n02106550-Rottweiler', 'n02106662-German_shepherd', 'n02107142-Doberman', 'n02107312-miniature_pinscher', 'n02107574-Greater_Swiss_Mountain_dog', 'n02107683-Bernese_mountain_dog', 'n02107908-Appenzeller', 'n02108000-EntleBucher', 'n02108089-boxer', 'n02108422-bull_mastiff', 'n02108551-Tibetan_mastiff', 'n02108915-French_bulldog', 'n02109047-Great_Dane', 'n02109525-Saint_Bernard', 'n02109961-Eskimo_dog', 'n02110063-malamute', 'n02110185-Siberian_husky', 'n02110627-affenpinscher', 'n02110806-basenji', 'n02110958-pug', 'n02111129-Leonberg', 'n02111277-Newfoundland', 'n02111500-Great_Pyrenees', 'n02111889-Samoyed', 'n02112018-Pomeranian', 'n02112137-chow', 'n02112350-keeshond', 'n02112706-Brabancon_griffon', 'n02113023-Pembroke', 'n02113186-Cardigan', 'n02113624-toy_poodle', 'n02113712-miniature_poodle', 'n02113799-standard_poodle', 'n02113978-Mexican_hairless', 'n02115641-dingo', 'n02115913-dhole', 'n02116738-African_hunting_dog']

# %%
# Get the dog Labels 
# get Labels by splitting the folder name at dash ;
breeds = [breed.split('-',1)[1] for breed in dog_classes]
# vlew some of the Labels 
breeds[:10]
# Out:
# ['Chihuahua',
#  'Japanese_spaniel',
#  'Maltese_dog',
#  'Pekinese',
#  'Shih-Tzu',
#  'Blenheim_spaniel',
#  'papillon',
#  'toy_terrier',
#  'Rhodesian_ridgeback',
#  'Afghan_hound']

# %%
# Get images full path and their labels
from itertools import chain
#X will have full address of each image
X =[]
#y will have its breed name
y=[]
fullpaths = ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\{}'.format(dog_class) for dog_class in dog_classes]
for counter, fullpath in enumerate(fullpaths):
    for imgname in os.listdir(fullpath):
        X.append([fullpath + '\\' + imgname])
        y.append(breeds[counter])
print(X[:10],"\n")
print(y[:10],"\n")
X=list(chain.from_iterable(X))
print(X[:10],"\n")
len(X)
# Out:
# [['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10074.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10131.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10621.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_1073.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10976.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11140.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11238.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11258.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11337.jpg'], ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11477.jpg']]
#
# ['Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua', 'Chihuahua']
#
# ['C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10074.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10131.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10621.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_1073.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10976.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11140.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11238.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11258.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11337.jpg', 'C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11477.jpg']
# 20580

# %%
# Random shuffle the images for learning |
import random 
# shuffle x and y 
combined= list(zip(X, y)) 
print(combined[:10],"\n") 
random.shuffle(combined)
print(combined[:10],"\n") 
X[:], y[:] = zip(*combined)
# Out:
# [('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10074.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10131.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10621.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_1073.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_10976.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11140.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11238.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11258.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11337.jpg', 'Chihuahua'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02085620-Chihuahua\\n02085620_11477.jpg', 'Chihuahua')]
#
# [('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02101388-Brittany_spaniel\\n02101388_2737.jpg', 'Brittany_spaniel'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02108422-bull_mastiff\\n02108422_1549.jpg', 'bull_mastiff'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02110806-basenji\\n02110806_979.jpg', 'basenji'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02093256-Staffordshire_bullterrier\\n02093256_5110.jpg', 'Staffordshire_bullterrier'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02087394-Rhodesian_ridgeback\\n02087394_11116.jpg', 'Rhodesian_ridgeback'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02098413-Lhasa\\n02098413_1719.jpg', 'Lhasa'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02091244-Ibizan_hound\\n02091244_3383.jpg', 'Ibizan_hound'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02099267-flat-coated_retriever\\n02099267_731.jpg', 'flat-coated_retriever'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02109047-Great_Dane\\n02109047_24710.jpg', 'Great_Dane'), ('C:\\Users\\abela\\Downloads\\Untitled Folder\\images\\Images\\n02108422-bull_mastiff\\n02108422_1939.jpg', 'bull_mastiff')]

# %%
# Display random dogs pictures
import matplotlib.pyplot as plt
#make your plot outputs appear and be stored within the notebook
# %matplotlib inline
from matplotlib.image import imread
plt.figure(figsize=(18,18))
 #Display random 9 images
#Len(X)=20580
for counter, i in enumerate(random.sample(range(0, len(X)), 9)):
    plt.subplot(3, 3, counter+1)
    plt.subplots_adjust(hspace=0.3)
    filename = X[i]
    image = imread(filename)
    plt. imshow(image)
    plt.title(y[i], fontsize=12)
plt.show()

# %%
# Choose a subsef to test code
X = X[:1000]
y = y[:1000]

# %%
# Convert labels to one-hot encoded labels
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
# Label and one-hot encoding y Labels
le = LabelEncoder()
le.fit(y) ;
y_ohe = to_categorical(le.transform(y), len(breeds))
print(y_ohe.shape)
y_ohe = np.array(y_ohe)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\4165247622.py in <module>
#       1 # Convert labels to one-hot encoded labels
#       2 from sklearn.preprocessing import LabelEncoder
# ----> 3 from keras.utils import to_categorical
#       4 # Label and one-hot encoding y Labels
#       5 le = LabelEncoder()
#
# ModuleNotFoundError: No module named 'keras'

# %%
from sklearn.model_selection import train_test_split 
from keras.preprocessing.image import img_to_array, load_img 
# load, resize images, and store as array !
img_data = np.array([img_to_array(load_img(img, target_size = (299,299))) for img in X]) 
print(img_data.shape)

#20 % of 1000 is 200 |
x_train, x_test, y_train, y_test = train_test_split(img_data, y_ohe,test_size = 0.2,random_state = 2) 
#20 % of 800 is 160 ;
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size = 0.2,random_state = 2) 
print('Training Dataset size: ', x_train.shape) 
print('Validation Dataset Size: ', x_val.shape) 
print('Testing Dataset Size: ', x_test.shape) 
print('Training Label Size: ', y_train.shape) 
print('Validation Label Size: ',y_val.shape) 
print('Testing Label Size: ', y_test.shape) 
# clear some space from memory |
import gc 
del img_data 
ge.collect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\3244777774.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from keras.preprocessing.image import img_to_array, load_img
#       3 # load, resize images, and store as array !
#       4 ing_data = np.array([ing_to_array(load_ing(ing, target_size = (299,299))) for img in X])
#       5 print(ing_data.shape)
#
# ModuleNotFoundError: No module named 'keras'

# %%
# Data Augnentation
from keras.applications.inception_v3 import preprocess_input 
from keras.preprocessing.image import ImageDataGenerator 
batch_size = 32 
# create train generator 
# using only preprocess_input because using pretrained models . use rescale=1./255 if training from scratch |
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                    rotation_range = 30
                                    width_shift_range = 0.2
                                    height_shift_range = 0.2
                                    horizontal_flip = True) 

train_generator = train_datagen.flow(x_train, y_train, 
                                    shuffle = False, batch_size = batch_size, seed = 1) 

# Create validation generator |
val_datagen = ImageDataGenerator (preprocessing_function=preprocess_input) # do not augnent validation data |

val_generator = val_datagen.flow(x_val, y_val,
                                shuffle = False, batch_size = batch size, seed = 1)
# Out:
#   File "C:\Users\abela\AppData\Local\Temp\ipykernel_7176\2666659034.py", line 9
#     width_shift_range = 0.2
#     ^
# SyntaxError: invalid syntax

# %%
img_id = 2
dog_generator = train_datagen.flow(x_train[img_id : img_id+1], y_train[img_id:img_id+1],
                                    shuffle = False, batch_size = batch_size, seed = 1) 

plt.figure(figsize=(20,20))
dogs = [next(dog_generator) for i in range(0,5)]
for counter, dog in enumerate(dogs):
    plt.subplot(1, 5, counter+1) 
    plt.imshow(dog[0][0])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\4014118681.py in <module>
#       1 img_id = 2
# ----> 2 dog_generator = train_datagen.flow(x_train[img_id : img_id+1], y_train[img_id:img_id+1],
#       3                                     shuffle = False, batch_size = batch_size, seed = 1)
#       4
#       5 plt.figure(figsize=(20,20))
#
# NameError: name 'train_datagen' is not defined

# %%
# Build Model Using Pre-trained Model i
from keras import models 
from keras import layers 
from keras.optimizers import Adam
from keras.layers import GlobalAveragePooling2D, Dense, Flatten, Dropout
from keras.applications.inception_v3 import Inceptionv3 
from keras.utils.np_utils import to_categorical
from keras.utils.vis_utils import plot_model

# Load Inceptionv3 pre-trained model |
base_model = Inceptionv3(ueights = 'imagenet', include_top = False, input_shape = (299,299,3)) 
model = models.Sequential () 
model.add(base_model) # add pre_trained Layers !
model.add(GlobalAveragePooling2D()) 
model.add(Dropout (0.3))
model.add(Dense(512, activation = 'relu')) 
model.add(Dense(512, activation = 'relu'))
model.add(Dense(len(breeds), activation = 'softmax'))
# Freeze pre-trained Layers 
print('Number of trainable weights before freezing the base layer:', len(model.trainable_weights))
model.layers[0].trainable = False
print('Number of trainable weights after freezing the base layer:', len(model.trainable_weights))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\316369713.py in <module>
#       1 # Build Model Using Pre-trained Model i
# ----> 2 from keras import models
#       3 from keras import layers
#       4 from keras.optimizers import Adam
#       5 from keras.layers import GlobalAveragePooling2D, Dense, Flatten, Dropout
#
# ModuleNotFoundError: No module named 'keras'

# %%
model.compile(Adam(lr=.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\1723566991.py in <module>
# ----> 1 model. compile(Adam(lr=.0001), loss='categorical_crossentropy', metrics=['accuracy'])
#       2 model. summary()
#
# NameError: name 'model' is not defined

# %%
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\3929530308.py in <module>
# ----> 1 plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
#
# NameError: name 'plot_model' is not defined

# %%
# Train Model
train_steps_per_epoch = x_train.shape[0] // batch_size
val_steps_per_epoch = x_val.shape[0] // batch_size
epochs = 20

history = model.fit_generator(train_generator,
                                steps_per_epoch = train_steps_per_epoch,
                                validation_data = val_generator,
                                validation_steps = val_steps_per_epoch,
                                epochs = epochs, verbose = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\3352764260.py in <module>
#       1 # Train Model
# ----> 2 train_steps_per_epoch = x_train.shape[0] // batch_size
#       3 val_steps_per_epoch = x_val.shape[0] // batch_size
#       4 epochs = 20
#       5
#
# NameError: name 'x_train' is not defined

# %%
# Plot Accuracy and Loss ;
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4)) 
t = f.suptitle('Transfer Learning Performance', fontsize=12) 
f.subplots_adjust(top=0.85, wspace=0.3) 

epoch_list = list(range(1,epochs+1)) 
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy') 
ax1.plot(epoch_list, history.history['val_accuracy'], label='validation Accuracy') 
ax1.set_xticks(np.arange(9, epochs+1, 5))
ax1.set_ylabel('Accuracy Value') 
ax1.set_xlabel('Epoch') 
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best") 

ax2.plot(epoch_list, history.history['loss'], label='Train Loss') 
ax2.plot(epoch_list, history.history['val_loss'], label='validation Loss') 
ax2.set_xticks(np.arange(0, epochs+1, 5)) 
ax2.set_ylabel('Loss Value') 
ax2.set_xlabel('Epoch') 
ax2.set_title('Loss') 
l2 = ax2.legend(loc="best")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\1056895913.py in <module>
#       4 f.subplots_adjust(top=0.85, wspace=0.3)
#       5
# ----> 6 epoch_list = list(range(1,epochs+1))
#       7 ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
#       8 ax1.plot(epoch_list, history.history['val_accuracy'], label='validation Accuracy')
#
# NameError: name 'epochs' is not defined

# %%
# Evaluate Hodel on Test Data 

x_testl = x_test / 255. # rescale to 6-1. Divide by 255 as its the max RGB value 
test_predictions = model.predict(x_test1) 

# get model predictions 
predictions = le.classes_[np.argmax(test_predictions,axis=1)] # get Labels and reverse back to get the text labels |
# get target Labels ;
target_labels = le.classes_[np.argmax(y_test,axis=1)]

# Store in dataframe
predict_df = pd.DataFrame({'Target_Labels': target_labels, 'Predictions': predictions}) 
predict_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\1209046354.py in <module>
#       1 # Evaluate Hodel on Test Data
#       2
# ----> 3 x_testl = x_test / 255. # rescale to 6-1. Divide by 255 as its the max RGB value
#       4 test_predictions = model.predict(x_test1)
#       5
#
# NameError: name 'x_test' is not defined

# %%
correct = (target_labels == predictions) 
accuracy = correct.sum() / correct.size 
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\1618958980.py in <module>
# ----> 1 correct = (target_labels == predictions)
#       2 accuracy = correct.sum() / correct.size
#       3 print(accuracy)
#
# NameError: name 'target_labels' is not defined

# %%
from model_evaluation_utils import get_metrics 
get_metrics(true_labels=target_labels,
            predicted_labels=predictions)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\295274634.py in <module>
# ----> 1 from model_evaluation_utils import get_metrics
#       2 get_metrics(true_labels=target_labels,
#       3             predicted_labels=predictions)
#
# ModuleNotFoundError: No module named 'model_evaluation_utils'

# %%
plt.figure(Figsize=(30,40)) 
for counter, i in enumerate(random.sample(range(0, len(y_test)), 30)): # random 30 images |
    plt.subplot(6, 5, counter+1) 
    plt.subplots_adjust(hspace=0.6) 
    actual = str(target_labels[i]) 
    predicted = str(predictions[i]) 
    conf = str(max(test_predictions[i])) 
    plt.imshow(x_test[i]/255.0) 
    plt.axis('off') 
    plt.title('Actual: ' + actual + '\nPredict: ' + predicted + '\nConf: ' + conf, fontsizes=18) 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\2460258683.py in <module>
# ----> 1 plt.figure(Figsize=(30,40))
#       2 for counter, i in enumerate(random.sample(range(0, len(y_test)), 30)): # random 30 images |
#       3     plt.subplot(6, 5, counter+1)
#       4     plt.subplots_adjust(hspace=0.6)
#       5     actual = str(target_labels[i])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     806                 RuntimeWarning)
#     807
# --> 808         manager = new_figure_manager(
#     809             num, figsize=figsize, dpi=dpi,
#     810             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in new_figure_manager(*args, **kwargs)
#     325     """Create a new figure manager instance."""
#     326     _warn_if_gui_out_of_main_thread()
# --> 327     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#     328
#     329
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in new_figure_manager(num, FigureClass, *args, **kwargs)
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#      28
#      29
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2290             %(Figure:kwdoc)s
#    2291         """
# -> 2292         super().__init__(**kwargs)
#    2293
#    2294         if layout is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in __init__(self, **kwargs)
#     214         self.stale = True
#     215         self.suppressComposite = None
# --> 216         self.set(**kwargs)
#     217
#     218     def _get_draw_artists(self, renderer):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Figure' object has no property 'Figsize'

# %%
from flask import Flask, flash, request, redirect, url_for, render_template
import urlib.request
import os
from werkzeug.utils import secure_filename
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import img_to_array, load_img

app=Flask(__name__)
UPLOAD_FOLDER='static/uploads'
app.secret_key="secret key"
app.config['UPLOAD_FOLDER']=UPLOAD_FOLDER
app.config['MAX_CONTENT_LENGTH']=16*1024*1024

ALLOWED_EXTENSIONS=set(['png','jpg','jpeg','gif'])

def allowed_files(filename):
    return '.' in filename and filename.rsplit('.',1)[1].lower() in ALLOWED_EXTENSIONS

@app.route('/')
def home():
    return render_template('start.html')

@app.route('/',methods=['POST'])
def upload_image():
    if 'file' not in request.files:
        flash('No file part')
        return redirect(request.url)
    file=request.files['file']
    if file.filename=='':
        flash('No image selected for uploading')
        return redirect(request.url)
    if file and allowed_file(file.filename):
        filename=secure filename(file,filename)
        file.save(os.path.join(app.config['UPLOAD_FOLDER'],filename))
        fullpaths=['C:\\Users\\abela\\Downloads\\Untitled Folder\\static\\uploads\\{}'.format(filename)]
        img_data=np.array([img_to_array(load_img(img,target_size=(299,299))) for img in fullpaths])
        x_test1=img_data/255.
        test_predictions=model.predict(x_test1)
        predictions=le.classes_[np.argmax(test_predictionss,axis=1)]
        name=predictions[0].upper().replace("_"," ")
        return render_template('result.html',prediction=name,src="https://simple.wikipedia.org/wiki/"+predictions[0])
  
if __name__=="__main__":
    app.run()
# Out:
#   File "C:\Users\abela\AppData\Local\Temp\ipykernel_7176\1193600408.py", line 34
#     filename=secure filename(file,filename)
#                     ^
# SyntaxError: invalid syntax
